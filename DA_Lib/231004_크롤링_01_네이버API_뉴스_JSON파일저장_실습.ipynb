# %% [markdown]
# # 1. 네이버 뉴스 Crawling with Naver Open API
# - 네이버 개발자 가입 : 서비스 API > 검색 > [오픈 API 이용 신청]
# - 검색 API 사용 신청 : Products > 검색 > [오픈 API 이용 신청]
#
# https://developers.naver.com/main/

# %%
# 네이버 검색 API 예제 -  블로그 검색 예제를 뉴스 검색 예제로 수정하여 실행
import os
import sys
import urllib.request
client_id = "vKaPzWy9SxfKMNgpCnAV"
client_secret = "IPV7F5oYWM"
encText = urllib.parse.quote("한가위")

#여기부터가 request 객체 만드는 부분.
url = "https://openapi.naver.com/v1/search/news?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

#request 객체를 보내서 요청하고
response = urllib.request.urlopen(request)

#응답을 받아서 처리를 하는 부분.
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 04 Oct 2023 13:29:38 +0900",
# 	"total":193744,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"[김형준 칼럼] '행동하는 민생'이 정답이다.",
# 			"originallink":"http:\/\/www.ftoday.co.kr\/news\/articleView.html?idxno=309849",
# 			"link":"http:\/\/www.ftoday.co.kr\/news\/articleView.html?idxno=309849",
# 			"description":"최근 외교, 안보 정책에 집중했던 윤석열 대통령은 추석 영상 메시지를 통해 &quot;민생이 늘 <b>한가위<\/b> 같도록 정부도 최선을 다하겠다&quot;고 했다. 추석 연휴 기간 공무원 격려, 군부대 시찰 등 여러 민생 행보를 이어갔다. 정치권... ",
# 			"pubDate":"Wed, 04 Oct 2023 13:16:00 +0900"
# 		},
# 		{
# 			"title":"<b>한가위<\/b>는 가족·이웃간 희망의 믿음을 확인하는 자리",
# 			"originallink":"http:\/\/www.g-enews.com\/ko-kr\/news\/article\/news_all\/20231003103635333e8b8a793f7_1\/article.html",
# 			"link":"http:\/\/www.g-enews.com\/ko-kr\/news\/article\/news_all\/20231003103635333e8b8a793f7_1\/article.html",
# ...

# %% [markdown]
# # 2. urllib : URL 작업용 패키지 (built-in)
# * import urllib
# * HTTP, FTP, SMTP 등과 같은 프로토콜을 사용하여 URL을 열고 읽고 쓰는 기능 제공
#
# * https://ctkim.tistory.com/entry/%ED%8C%8C%EC%9D%B4%EC%8D%AC-urllib-%EB%AA%A8%EB%93%88
#    - urllib.request : 다양한 방식으로 URL을 열고 데이터를 가져오는 기능 제공
#    - urllib.response : urllib가 사용하는 응답 클래스
#    - urllib.parse : URL 파싱, 인코딩, 디코딩
#    - urllib.robotparser : robots.txt 파일의 parsing
#
#
# ## 2-1. urllib으로 Open API 사용하기
#   - 특수문자 및 비ASCII코드를 url에 사용할 수 있도록 변경 : *string* = **urllib.parse.quote**(*string*)
#   - 요청 메시지 생성
#     - Request 객체 생성 : *request_object* = **urllib.request.Request**(*url*)
#     - Request 객체 Header에 API 사용을 위한 정보 추가 : *request_object*.**add_header**(*key*, *val*)
#   - API 요청 및 결과 받기
#     - Request 객체로 url 열고 HTTPResponse 객체 받기 : *Response* = **urllib.request.urlopen**(*Request*)
#     - urlopen 결과 상태 정보 얻기 : *Response*.**getcode()** (**status**)
#     - Response 객체에서 요청 결과 얻기 : *Response*.**read()**
#     - 결과에 한글이 표함된 경우 UTF-8로 디코팅 : *string*.**decode**('utf-8')

# %%
# 네이버 검색 API 예제 기반으로 네이버 검색 API 동작 방식 확인
import os
import sys
import urllib.request
import json

#필요한 데이터 초기화
client_id = "vKaPzWy9SxfKMNgpCnAV"
client_secret = "IPV7F5oYWM"
const_start = 1
const_display = 10


#사용자로부터 검색어 입력받도록 변경하기
# keyword = input("검색어를 입력하세요 :")
# encText = urllib.parse.quote(keyword)
encText = urllib.parse.quote("한가위")


#사용할 변수 초기화
start= const_start
display = const_display
resultList = []


#여기부터가 request 객체 만드는 부분 + display, start 파라미터 추가.
url = "https://openapi.naver.com/v1/search/news?query=" + encText# JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과

#3qjs rufrhkfmf
while start < 30:
    reqUrl = url + f"&start={start}&display={display}"
    request = urllib.request.Request(reqUrl)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)

    #request 객체를 보내서 요청하고
    response = urllib.request.urlopen(request)

    #응답을 받아서 처리를 하는 부분.
    rescode = response.getcode()
    if(rescode==200):
        #read()하면 string이 나오고 거기에 한글 위해서 디코딩.
        response_body = response.read().decode('utf-8')
        #resultList에 검색 결과 저장
        resultJSON = json.loads(response_body)
        resultList.append(resultJSON['items'])
        print(resultJSON['items'])
    else:
        print("Error Code:" + rescode)        
    start += display
# Out:
# [{'title': '도의회, &quot;새만금 정상화 하라&quot;', 'originallink': 'http://sjbnews.com/news/news.php?number=794099', 'link': 'http://sjbnews.com/news/news.php?number=794099', 'description': '<b>한가위</b> 연휴에도 새만금 개발사업 정상화를 촉구하는 도의원들의 릴레이식 대정부 삭발 단식 투쟁이 이어졌다. 전북도의회 국주영은 의장(사진)은 추석 당일인 지난달 29일과 30일 이틀간 도의회 청사 앞 천막 농성장에서... ', 'pubDate': 'Wed, 04 Oct 2023 13:54:00 +0900'}, {'title': '쌀 클레이로 송편 빚는 초등생들', 'originallink': 'http://sjbnews.com/news/news.php?number=794102', 'link': 'http://sjbnews.com/news/news.php?number=794102', 'description': '3일 추석을 맞아 가족들과 농진청(청장 조재호) 농업과학관을 방문한 어린이들이 쌀클레이 체험을 하며 즐거운 <b>한가위</b> 연휴를 보내고 있다.', 'pubDate': 'Wed, 04 Oct 2023 13:54:00 +0900'}, {'title': '강강수월래 하는 어린이들', 'originallink': 'http://sjbnews.com/news/news.php?number=794101', 'link': 'http://sjbnews.com/news/news.php?number=794101', 'description': '추석을 맞아 전주시 완산구 미래유치원 어린이들이 지난달 27일 전통 민속놀이인 강강수월래를 배우며 즐거운 <b>한가위</b>를 맞고 있다.', 'pubDate': 'Wed, 04 Oct 2023 13:54:00 +0900'}, {'title': "'식냥이'가 <b>한가위</b> 맞아, 전주 한옥마
# ...

# %% [markdown]
# # 3. json : JSON 데이터 파싱,생성 (built-in)
# * import json
# * JSON 문자열을 파이썬 객체로 변환 : *pyObject* = **json.loads**(*jsonString*)
# * 파이썬 객체를 JSON 문자열로 변환 : *jsonString* = **json.dumps**(*pyObject*)
#    - ensure_ascii=True : 한글일때는 False로 변경하기
#    - indent=None : 가독성을 높이기 위해 숫자 지정하기
# * JSON 파일을 파이썬 객체로 로딩 : *pyObject* = **json.load**()
# * 파이썬 객체를 JSON 파일에 저장 : **json.dump**(*pyObject*, *fileObject*)
#
# https://docs.python.org/3/library/json.html
#
#
# # 4. 파이썬 예외처리 : try + except + else + finally

# %% [markdown]
# # [ 프로그램 Workflow ]
# * Naver 검색 API로 검색 결과를 json으로 받아서 파일로 저장
#    - start부터 display 수만큼 검색 결과를 json으로 가져옴
#    - 검색 결과는 json의 'items'에 들어 있음
#    - 검색 결과 수는 'display'에 들어 있음
#
# 1. 필요 데이터 설정
#    1. API 관련 데이터 : client_id, cliend_secret
#    1. 검색어는 입력받기 : keyword
#    1. 검색 관련 초기값 : const_start, const_display
#    1. 검색 결과 저장 변수 : jsonResultAll
#
# 1. 네이버 뉴스를 검색하여 리스트로 저장
#    1. 네이버 뉴스 검색 : **searchNaverNews()** -> 파이썬 json 데이터
#        1. url 구성하기
#        1. url 접속과 검색 요청하기
#        1. url 요청결과를 응답 json으로 받기 (json.loads)
#    1. 응답데이터를 리스트에 저장 : **setNewSearchResult** -> List
#    1. 응답데이터가 없을 때까지 반복
#
# 1. 리스트를 JSON 파일로 저장 : **saveSearchResult** (json.dumps)

# %%
import os
import sys
import urllib.request
import json

#필요 데이터 설정
client_id = "vKaPzWy9SxfKMNgpCnAV"
client_secret = "IPV7F5oYWM"
const_url = "https://openapi.naver.com/v1/search/news?query="
const_start = 1
const_display = 10

#
def searchNaverNews(keyword, start, display):
    encText = urllib.parse.quote(keyword)
    reqUrl = const_url + f"{encText}&start={start}&display={display}"
    request = urllib.request.Request(reqUrl)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)

    result_json = None
    
    try:
        response = urllib.request.urlopen(request)
        rescode = response.getcode()
        
        if(rescode==200):
            response_body = response.read().decode('utf-8')
            result_json = json.loads(response_body)
            
    except Exception as e:
        print(e)
        print(f"Error : {reqUrl}")
        
    return result_json #JSON 데이터 제대로 있을 때만 리턴.



def setNewSearchResult(json_result):
    #파이썬? 객체에서 검색 결과 부분을 찾아서 주기
#     result_dict = json.loads(response_body)
    return json_result['items'] #List 결과물을 수정해서 저장하고 싶을때. json의 내용을 업그레이드 해서?


def saveSearchResult(filename, list_result_all):
    with open(filename, "w", encoding="utf8") as outfile:
        json_string = json.dumps(list_result_all, ensure_ascii=False, indent=4)
        outfile.write(json_string)
        print(f"{filename} is saved...")
    return None

json_result_all = [] #검색결과 저장

keyword = input("검색어를 입력하세요 :")

#사용할 변수 초기화
start = const_start
display = const_display

#네이버 뉴스를 검색해서 리스트로 저장
#응답데이터가 없을 때까지 반복
json_result = searchNaverNews(keyword, start, display)#최초의 검색 실행
while json_result != None:
    #응답데이터를 리스트에 저장
    list_result = setNewSearchResult(json_result)
    json_result_all.append(list_result)
    
    #네이버 뉴스 검색
    start += json_result['display'] #검색한게 몇개인지 찾아서 더해주는 게 맞음
    json_result = searchNaverNews(encText, start, display)
    
#모든 검색 결과 담긴 리스트를 JSON 파일로 저장
    if json_result != None:
        print(f"{keyword}[{start}] : Search Request Success")
    else:
        print(f"{keyword}[{start}] : Failed..")

saveSearchResult(f"{keyword}_news.json", json_result_all)
# Out:
# 검색어를 입력하세요 :물티슈
# 물티슈[11] : Search Request Success
# 물티슈[21] : Search Request Success
# 물티슈[31] : Search Request Success
# 물티슈[41] : Search Request Success
# 물티슈[51] : Search Request Success
# 물티슈[61] : Search Request Success
# 물티슈[71] : Search Request Success
# 물티슈[81] : Search Request Success
# 물티슈[91] : Search Request Success
# 물티슈[101] : Search Request Success
# 물티슈[111] : Search Request Success
# 물티슈[121] : Search Request Success
# 물티슈[131] : Search Request Success
# 물티슈[141] : Search Request Success
# 물티슈[151] : Search Request Success
# 물티슈[161] : Search Request Success
# 물티슈[171] : Search Request Success
# 물티슈[181] : Search Request Success
# 물티슈[191] : Search Request Success
# 물티슈[201] : Search Request Success
# 물티슈[211] : Search Request Success
# 물티슈[221] : Search Request Success
# 물티슈[231] : Search Request Success
# 물티슈[241] : Search Request Success
# 물티슈[251] : Search Request Success
# 물티슈[261] : Search Request Success
# 물티슈[271] : Search Request Success
# ...

# %% [markdown]
# # 평탄화 extend

# %%
import os
import sys
import urllib.request
import json

#필요 데이터 설정
client_id = "vKaPzWy9SxfKMNgpCnAV"
client_secret = "IPV7F5oYWM"
const_url = "https://openapi.naver.com/v1/search/news?query="
const_start = 1
const_display = 10


def searchNaverNews(keyword, start, display):
    encText = urllib.parse.quote(keyword)
    reqUrl = const_url + f"{encText}&start={start}&display={display}"
    request = urllib.request.Request(reqUrl)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)

    result_json = None
    
    try:
        response = urllib.request.urlopen(request)
        rescode = response.getcode()
        
        if(rescode==200):
            response_body = response.read().decode('utf-8')
            result_json = json.loads(response_body)
            
    except Exception as e:
        print(e)
        print(f"Error : {reqUrl}")
        
    return result_json #JSON 데이터 제대로 있을 때만 리턴.



def setNewSearchResult(json_result):
    #파이썬? 객체에서 검색 결과 부분을 찾아서 주기
#     result_dict = json.loads(response_body)
    return json_result['items'] #List 결과물을 수정해서 저장하고 싶을때. json의 내용을 업그레이드 해서?


def saveSearchResult(filename, list_result_all):
    with open(filename, "w", encoding="utf8") as outfile:
        json_string = json.dumps(list_result_all, ensure_ascii=False, indent=4)
        outfile.write(json_string)
        print(f"{filename} is saved...")
    return None

json_result_all = [] #검색결과 저장

keyword = input("검색어를 입력하세요 :")

#사용할 변수 초기화
start = const_start
display = const_display

#네이버 뉴스를 검색해서 리스트로 저장
#응답데이터가 없을 때까지 반복
json_result = searchNaverNews(keyword, start, display)#최초의 검색 실행
while json_result != None:
    #응답데이터를 리스트에 저장
    list_result = setNewSearchResult(json_result)
    json_result_all.extend(list_result)
    
    #네이버 뉴스 검색
    start += json_result['display'] #검색한게 몇개인지 찾아서 더해주는 게 맞음
    json_result = searchNaverNews(encText, start, display)
    
#모든 검색 결과 담긴 리스트를 JSON 파일로 저장
    if json_result != None:
        print(f"{keyword}[{start}] : Search Request Success")
    else:
        print(f"{keyword}[{start}] : Failed..")

saveSearchResult(f"{keyword}_news.json", json_result_all)
# Out:
# 검색어를 입력하세요 :보리차
# 보리차[11] : Search Request Success
# 보리차[21] : Search Request Success
# 보리차[31] : Search Request Success
# 보리차[41] : Search Request Success
# 보리차[51] : Search Request Success
# 보리차[61] : Search Request Success
# 보리차[71] : Search Request Success
# 보리차[81] : Search Request Success
# 보리차[91] : Search Request Success
# 보리차[101] : Search Request Success
# 보리차[111] : Search Request Success
# 보리차[121] : Search Request Success
# 보리차[131] : Search Request Success
# 보리차[141] : Search Request Success
# 보리차[151] : Search Request Success
# 보리차[161] : Search Request Success
# 보리차[171] : Search Request Success
# 보리차[181] : Search Request Success
# 보리차[191] : Search Request Success
# 보리차[201] : Search Request Success
# HTTP Error 429: Too Many Requests
# Error : https://openapi.naver.com/v1/search/news?query=%25ED%2595%259C%25EA%25B0%2580%25EC%259C%2584&start=211&display=10
# 보리차[211] : Failed..
# 보리차_news.json is saved...

# %%
import os
import sys
import urllib.request
import json

#필요 데이터 설정
client_id = "vKaPzWy9SxfKMNgpCnAV"
client_secret = "IPV7F5oYWM"
const_url = "https://openapi.naver.com/v1/search/news?query="
const_start = 1
const_display = 10


def searchNaverNews(keyword, start, display):
    encText = urllib.parse.quote(keyword)
    reqUrl = const_url + f"{encText}&start={start}&display={display}"
    request = urllib.request.Request(reqUrl)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)

    result_json = None
    
    try:
        response = urllib.request.urlopen(request)
        rescode = response.getcode()
        
        if(rescode==200):
            response_body = response.read().decode('utf-8')
            result_json = json.loads(response_body)

            idx = 0

            for item in result_json['items']:
                item['index'] = idx
                idx += 1
            
    except Exception as e:
        print(e)
        print(f"Error : {reqUrl}")
        
    return result_json #JSON 데이터 제대로 있을 때만 리턴.


#######################################################
#파이썬? 객체에서 검색 결과 부분을 찾아서 주기
def setNewSearchResult(json_result):
    
    return json_result['items'] #List 결과물을 수정해서 저장하고 싶을때. json의 내용을 업그레이드 해서?


def saveSearchResult(filename, list_result_all):
    with open(filename, "w", encoding="utf8") as outfile:
        json_string = json.dumps(list_result_all, ensure_ascii=False, indent=4)
        outfile.write(json_string)
        print(f"{filename} is saved...")
    return None

json_result_all = [] #검색결과 저장

keyword = input("검색어를 입력하세요 :")

#사용할 변수 초기화
start = const_start
display = const_display

#네이버 뉴스를 검색해서 리스트로 저장
#응답데이터가 없을 때까지 반복
json_result = searchNaverNews(keyword, start, display)#최초의 검색 실행
while json_result != None:
    #응답데이터를 리스트에 저장
    list_result = setNewSearchResult(json_result)
    json_result_all.extend(list_result)
    
    #네이버 뉴스 검색
    start += json_result['display'] #검색한게 몇개인지 찾아서 더해주는 게 맞음
    json_result = searchNaverNews(keyword, start, display)
    
#모든 검색 결과 담긴 리스트를 JSON 파일로 저장
    if json_result != None:
        print(f"{keyword}[{start}] : Search Request Success")
    else:
        print(f"{keyword}[{start}] : Failed..")

saveSearchResult(f"{keyword}_news.json", json_result_all)
# Out:
# 강아지[11] : Search Request Success
# 강아지[21] : Search Request Success
# 강아지[31] : Search Request Success
# 강아지[41] : Search Request Success
# 강아지[51] : Search Request Success
# 강아지[61] : Search Request Success
# 강아지[71] : Search Request Success
# 강아지[81] : Search Request Success
# 강아지[91] : Search Request Success
# HTTP Error 429: Too Many Requests
# Error : https://openapi.naver.com/v1/search/news?query=%EA%B0%95%EC%95%84%EC%A7%80&start=101&display=10
# 강아지[101] : Failed..
# 강아지_news.json is saved...
