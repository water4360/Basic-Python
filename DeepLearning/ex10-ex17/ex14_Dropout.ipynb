# %%
# !nvidia-smi
# Out:
# Thu Jul  6 10:26:32 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical

import numpy as np
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship','truck' ]
NUM_CLASSES = 10


if y_test.shape[1] == 1:
  x_train = x_train/255.
  x_test = x_test/255.
  y_train = to_categorical(y_train, NUM_CLASSES)
  y_test = to_categorical(y_test, NUM_CLASSES)

model = keras.Sequential([
    keras.layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,3)),
    keras.layers.Conv2D(32, (3,3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.Flatten(),
    keras.layers.Dense(64, activation = 'relu'),
    keras.layers.Dense(10, activation = 'softmax')
])

model.compile(optimizer='adam',
             loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=30, validation_data=(x_test,y_test))
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 9s 5ms/step - loss: 1.5124 - accuracy: 0.4465 - val_loss: 1.1750 - val_accuracy: 0.5781
# Epoch 2/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.0184 - accuracy: 0.6394 - val_loss: 0.9075 - val_accuracy: 0.6809
# Epoch 3/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.8262 - accuracy: 0.7114 - val_loss: 0.8389 - val_accuracy: 0.7072
# Epoch 4/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7008 - accuracy: 0.7544 - val_loss: 0.7884 - val_accuracy: 0.7314
# Epoch 5/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.6009 - accuracy: 0.7864 - val_loss: 0.7969 - val_accuracy: 0.7262
# Epoch 6/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5193 - accuracy: 0.8148 - val_loss: 0.7924 - val_accuracy: 0.7409
# Epoch 7/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.4404 - accuracy: 0.8465 - val_loss: 0.8473 - val_accuracy: 0.7335
# Epoch 8/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.3793 - accuracy: 0.8660 - val_loss: 0.9045 - val_accuracy: 0.7297
# Epoch 9/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.3237 - accuracy: 0.8861 - val_loss: 1.0038 - val_accuracy: 0.7201
# Epoch 10/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.2813 - accuracy: 0.9002 - val_loss: 1.0910 - val_accuracy: 0.7294
# Epoch 11/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.2464 - accuracy: 0.9116 - val_loss: 1.0712 - val_accuracy: 0.7373
# Epoch 12/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.2240 - accuracy: 0.9206 - val_loss: 1.1954 - val_accuracy: 0.7315
# Epoch 13/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1999 - accuracy: 0.9287 - val_loss: 1.2402 - val_accuracy: 0.7270
# Epoch 14/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1859 - accuracy: 0.9343 - val_loss: 1.3263 - val_accuracy: 0.7261
# Epoch 15/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1771 - accuracy: 0.9377 - val_loss: 1.2706 - val_accuracy: 0.7252
# Epoch 16/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1642 - accuracy: 0.9431 - val_loss: 1.3506 - val_accuracy: 0.7292
# Epoch 17/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1546 - accuracy: 0.9469 - val_loss: 1.4289 - val_accuracy: 0.7347
# Epoch 18/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1501 - accuracy: 0.9472 - val_loss: 1.4200 - val_accuracy: 0.7331
# Epoch 19/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1486 - accuracy: 0.9490 - val_loss: 1.5546 - val_accuracy: 0.7303
# Epoch 20/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1381 - accuracy: 0.9524 - val_loss: 1.4972 - val_accuracy: 0.7287
# Epoch 21/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1423 - accuracy: 0.9510 - val_loss: 1.5028 - val_accuracy: 0.7273
# Epoch 22/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1369 - accuracy: 0.9540 - val_loss: 1.6808 - val_accuracy: 0.7134
# Epoch 23/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1271 - accuracy: 0.9565 - val_loss: 1.7241 - val_accuracy: 0.7206
# Epoch 24/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1344 - accuracy: 0.9543 - val_loss: 1.6432 - val_accuracy: 0.7250
# Epoch 25/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1284 - accuracy: 0.9567 - val_loss: 1.7172 - val_accuracy: 0.7260
# Epoch 26/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1174 - accuracy: 0.9614 - val_loss: 1.7921 - val_accuracy: 0.7310
# Epoch 27/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1199 - accuracy: 0.9599 - val_loss: 1.7603 - val_accuracy: 0.7322
# Epoch 28/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1162 - accuracy: 0.9604 - val_loss: 1.8149 - val_accuracy: 0.7294
# Epoch 29/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1209 - accuracy: 0.9601 - val_loss: 1.7501 - val_accuracy: 0.7236
# Epoch 30/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1176 - accuracy: 0.9615 - val_loss: 1.6754 - val_accuracy: 0.7273

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
model = keras.Sequential([
    keras.layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,3)),
    keras.layers.Conv2D(32, (3,3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.Flatten(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64, activation = 'relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10, activation = 'softmax')
])

model.compile(optimizer='adam',
             loss='categorical_crossentropy',
              metrics=['accuracy'])

history2 = model.fit(x_train, y_train, epochs=30, validation_data=(x_test,y_test))
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.7631 - accuracy: 0.3414 - val_loss: 1.3663 - val_accuracy: 0.4994
# Epoch 2/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3421 - accuracy: 0.5158 - val_loss: 1.1265 - val_accuracy: 0.6053
# Epoch 3/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.1493 - accuracy: 0.5968 - val_loss: 1.0038 - val_accuracy: 0.6499
# Epoch 4/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.0317 - accuracy: 0.6368 - val_loss: 0.9272 - val_accuracy: 0.6757
# Epoch 5/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9594 - accuracy: 0.6668 - val_loss: 0.8822 - val_accuracy: 0.6935
# Epoch 6/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8995 - accuracy: 0.6888 - val_loss: 0.8450 - val_accuracy: 0.7055
# Epoch 7/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8524 - accuracy: 0.7039 - val_loss: 0.8049 - val_accuracy: 0.7200
# Epoch 8/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8003 - accuracy: 0.7239 - val_loss: 0.7587 - val_accuracy: 0.7357
# Epoch 9/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7633 - accuracy: 0.7376 - val_loss: 0.8055 - val_accuracy: 0.7261
# Epoch 10/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7379 - accuracy: 0.7445 - val_loss: 0.7713 - val_accuracy: 0.7344
# Epoch 11/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7163 - accuracy: 0.7533 - val_loss: 0.7439 - val_accuracy: 0.7512
# Epoch 12/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6862 - accuracy: 0.7633 - val_loss: 0.7640 - val_accuracy: 0.7502
# Epoch 13/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6684 - accuracy: 0.7699 - val_loss: 0.7657 - val_accuracy: 0.7481
# Epoch 14/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6536 - accuracy: 0.7770 - val_loss: 0.7439 - val_accuracy: 0.7543
# Epoch 15/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6281 - accuracy: 0.7829 - val_loss: 0.7476 - val_accuracy: 0.7519
# Epoch 16/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6128 - accuracy: 0.7885 - val_loss: 0.7377 - val_accuracy: 0.7633
# Epoch 17/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6125 - accuracy: 0.7894 - val_loss: 0.7484 - val_accuracy: 0.7519
# Epoch 18/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5836 - accuracy: 0.7975 - val_loss: 0.7121 - val_accuracy: 0.7677
# Epoch 19/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5820 - accuracy: 0.7990 - val_loss: 0.7722 - val_accuracy: 0.7640
# Epoch 20/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5615 - accuracy: 0.8058 - val_loss: 0.7760 - val_accuracy: 0.7638
# Epoch 21/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5531 - accuracy: 0.8092 - val_loss: 0.7638 - val_accuracy: 0.7602
# Epoch 22/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5505 - accuracy: 0.8129 - val_loss: 0.7517 - val_accuracy: 0.7703
# Epoch 23/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5398 - accuracy: 0.8147 - val_loss: 0.7974 - val_accuracy: 0.7593
# Epoch 24/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5238 - accuracy: 0.8195 - val_loss: 0.7899 - val_accuracy: 0.7715
# Epoch 25/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5177 - accuracy: 0.8218 - val_loss: 0.7209 - val_accuracy: 0.7698
# Epoch 26/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5024 - accuracy: 0.8270 - val_loss: 0.7325 - val_accuracy: 0.7761
# Epoch 27/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4946 - accuracy: 0.8306 - val_loss: 0.7764 - val_accuracy: 0.7682
# Epoch 28/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4958 - accuracy: 0.8299 - val_loss: 0.7703 - val_accuracy: 0.7695
# Epoch 29/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4798 - accuracy: 0.8351 - val_loss: 0.8051 - val_accuracy: 0.7773
# Epoch 30/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4800 - accuracy: 0.8347 - val_loss: 0.7611 - val_accuracy: 0.7789

# %%
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
